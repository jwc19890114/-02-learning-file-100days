# %% [markdown]
# ## 逻辑回归模型
# 逻辑回归在上世纪被用于生物科学。继而在很多社会学应用中被使用。使用场景：当因变量（目标）是分类的。
# - 垃圾邮件预测
# - 恶性肿瘤判别
#
# 在判断垃圾邮件的场景中，如果使用线性回归，就需要设定判断阈值。当预测值为0.4，而阈值为0.5的时候，数据就会分类为非恶性（在实际情况下，可能会导致严重的后果）。**可见线性回归不适合分类问题**
#
# ### 简单逻辑回归
# 完整源码：https://github.com/SSaishruthi/LogisticRegression_Vectorized_Implementation/blob/master/Logistic_Regression.ipynb
#
# ***模型***
# - 输出：0或1
# - 假设：z=wx+b
# - hΘ(x) = sigmoid (Z)
# - ![sigmoid](https://cdn-images-1.medium.com/max/1600/1*RqXFpiNGwdiKBWyLJc_E7g.png)
# 如果"Z"趋近正无穷，Y（预测）为1，反之Y为0
#
# ***对假设的分析***
# 假设的输出为可能性评估。被用于推断在给定输入X时预测值对实际值的信心。举例如下：
# X=[x0 x1]=[1 IP-Address]***原文给出的这个公式很费解啊直接看下面的数学***
# 基于x1的数值，获得评估可能性为0.8，说明邮件有80%的可能是垃圾邮件。
# ![数学化的表达](https://cdn-images-1.medium.com/max/1600/1*i_QQvUzXCETJEelf4mLx8Q.png)
# 这证明了“逻辑回归”。将数据拟合到线性回归模型中，然后通过预测目标分类因变量的逻辑函数对其进行操作。
#
# ### 逻辑回归类别
# - 二元逻辑回归
# 分类反馈只有两个结果。
# - 多项式逻辑回归
# 三个以上无序分类。
# - 序数逻辑回归
# 三个以上有序分类。如电影的排名。
#
# ### 决策边界
# 为了预测数据属于哪一类别，需要设定阈值。基于阈值，获得的评估概率就能够被划入对应分类中***和线性分类一样***。
# 例如：预测值>=0.5，邮件分类为非垃圾邮件。
# 决策边界可以是线性的也可以是非线性的。可以通过增加多项式阶数以获得复杂的决策边界。
#
# ### 代价函数
# ![逻辑回归的代价函数](https://cdn-images-1.medium.com/max/1600/1*TqZ9myxIdLuKNmt8orCeew.png)
# **为什么代价函数使用线性而非逻辑？**
# 线性回归使用均方误差（mean squared error）作为它的代价函数。如果这个被逻辑回归使用，元素theta将会是非平滑，而梯度下降只有在平滑的函数中才能到达全局最小值。***说到底还是为了梯度下降时获取最小值***
#
# ### 代价函数解读***这部分本来想自己跑图出来，但是没有达到效果，就先借用原博客的图了***
# ![逻辑回归的代价函数](https://cdn-images-1.medium.com/max/1600/1*5AYaGPV-gjYUf37d2IhgTQ.jpeg)
# ![逻辑回归的代价函数](https://cdn-images-1.medium.com/max/1600/1*MFMIEUC_dobhJrRjGK7PBg.jpeg)
#
# ### 简化代价函数
# ![简化代价函数](https://cdn-images-1.medium.com/max/1600/1*ueEwU1dE0Yu-KpMJanf9AQ.png)
#
# ### 为什么使用这个代价函数
# ![最大似然](https://cdn-images-1.medium.com/max/1600/1*heGae4aZ-dN-rLsfx2-P9g.jpeg)
# ![最大似然](https://cdn-images-1.medium.com/max/1600/1*JIpaau-jFfvX2yR9L1YZ6A.jpeg)
# 负面作用是因为当我们训练时，需要通过最小化损失函数来最大化概率。假设样本来自相同的独立分布，降低成本将增加最大可能性。
#
# ### 推导梯度下降算法
# ![梯度下降公式](https://cdn-images-1.medium.com/max/1600/1*r7fhk417IOuq7meXIctGXg.jpeg)
# ![梯度下降公式](https://cdn-images-1.medium.com/max/1600/1*pJEi5f4gdVGezYev9MChBw.jpeg)

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x=np.arange(0.05,1,0.05)
y1=-np.log(1-x)
y2=-np.log(x)
plot1=plt.plot(x,y1,'-g',label="y0,-log10(1-Z)")
plot2=plt.plot(x,y2,'-b',label="y1,-log10(Z)")
plt.legend(loc='lower right')
plt.show()

# %%
import pandas as pd
df = pd.read_csv("ex2data1.txt", header=None)
train_data=df.values
print(df[0:4])
train_X=train_data[:,:-1]
train_y=train_data[:,-1:]
print(train_X[0:4])
print(train_y[0:4])
# Out:
#            0          1  2
# 0  34.623660  78.024693  0
# 1  30.286711  43.894998  0
# 2  35.847409  72.902198  0
# 3  60.182599  86.308552  1
# [[34.62365962 78.02469282]
#  [30.28671077 43.89499752]
#  [35.84740877 72.90219803]
#  [60.18259939 86.3085521 ]
#  [79.03273605 75.34437644]
#  [45.08327748 56.31637178]
#  [61.10666454 96.51142588]
#  [75.02474557 46.55401354]
#  [76.0987867  87.42056972]
#  [84.43281996 43.53339331]
#  [95.86155507 38.22527806]
#  [75.01365839 30.60326323]
#  [82.30705337 76.4819633 ]
#  [69.36458876 97.71869196]
#  [39.53833914 76.03681085]
#  [53.97105215 89.20735014]
#  [69.07014406 52.74046973]
#  [67.94685548 46.67857411]
#  [70.66150955 92.92713789]
#  [76.97878373 47.57596365]
#  [67.37202755 42.83843832]
#  [89.67677575 65.79936593]
#  [50.53478829 48.85581153]
#  [34.21206098 44.2095286 ]
#  [77.92409145 68.97235999]
#  [62.27101367 69.95445795]
#  [80.19018075 44.82162893]
#  [93.1143888  38.80067034]
#  [61.83020602 50.25610789]
# ...
